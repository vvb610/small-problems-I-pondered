# %% [markdown]
# # Clean Data from Downloaded Form

# %%
import numpy as np
import pandas as pd

# %%
diabetes = pd.read_csv('./Data/pima-indians-diabetes.csv')
diabetes.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
estranged_row = ['6', '148', '72', '35', '0', '33.6', '0.627', '50', '1']
diabetes.columns = ['times_pregnant', 'glucose_concentration', 'blood_pressure', 'Triceps_skinfold_thickness',
              '2_Hour_serum_insulin', 'BMI', 'diabetes_pedigree_function', 'Age', 'Class_Variable']
diabetes.loc[len(diabetes.index)] = estranged_row
diabetes
# Out:
#     times_pregnant glucose_concentration blood_pressure  \
# 0                1                    85             66
# 1                8                   183             64
# 2                1                    89             66
# 3                0                   137             40
# 4                5                   116             74
# ..             ...                   ...            ...
# 763              2                   122             70
# 764              5                   121             72
# 765              1                   126             60
# 766              1                    93             70
# 767              6                   148             72
#
#     Triceps_skinfold_thickness 2_Hour_serum_insulin   BMI  \
# 0                           29                    0  26.6
# 1                            0                    0  23.3
# 2                           23                   94  28.1
# ...

# %%
diabetes.to_csv('./Data/pima-indians-diabetes-cleaned.csv', index=False)
